# %%
import tensorflow as tf
from keras.models import load_model

q_eval = load_model('humvee_largestt_7_checkpoint_7.0.h5')

# %%
def filter_image(image):
    # If the image has 4 channels (RGBA), ignore the alpha channel
    if image.shape[2] == 4:
        image = image[:, :, :3]
    
    # Define the color masks for green and blue
    green_mask = (image[:, :, 0] == 0) & (image[:, :, 1] == 255) & (image[:, :, 2] == 0)
    blue_mask = (image[:, :, 0] == 255) & (image[:, :, 1] == 0) & (image[:, :, 2] == 0)
    
    # Create a black image (same shape as the input image)
    black_image = np.zeros_like(image)
    
    # Apply the masks to retain only green and blue pixels
    black_image[green_mask] = [0, 255, 0]
    black_image[blue_mask] = [255, 0, 0]
    
    return black_image

# %%
import numpy as np

def get_humvee_position(image):
    """
    Get the position of the blue dot (humvee) in the image.
    
    Parameters:
    - image (np.ndarray): The input image in which to find the blue dot.

    Returns:
    - tuple: A tuple containing the (x, y) coordinates of the blue dot,
      or None if the blue dot is not found.
    """
    # Define the blue color mask
    blue_mask = (image[:, :, 0] == 255) & (image[:, :, 1] == 0) & (image[:, :, 2] == 0)
    blue_coords = np.column_stack(np.where(blue_mask))
    
    if blue_coords.size == 0:
        # If no blue dot is found, return None
        return None
    
    # Use the average position if there are multiple blue pixels
    humvee_pos = np.mean(blue_coords, axis=0)
    
    return (humvee_pos[1], humvee_pos[0])  # Return as (x, y)

# %%
import cv2
import numpy as np

def get_state(image, prev_input):
    # Convert the image to grayscale for easier processing
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Find the blue dot position (humvee)
    blue_mask = (image[:, :, 0] == 255) & (image[:, :, 1] == 0) & (image[:, :, 2] == 0)
    blue_coords = np.column_stack(np.where(blue_mask))
    
    if blue_coords.size == 0:
        # If no blue dot is found, return a default state
        return np.zeros(9+6, dtype=np.float32)
    
    humvee_pos = np.mean(blue_coords, axis=0)  # Use the average position if there are multiple pixels

    # Find the green dot positions
    green_mask = (image[:, :, 0] == 0) & (image[:, :, 1] == 255) & (image[:, :, 2] == 0)
    green_coords = np.column_stack(np.where(green_mask))

    if green_coords.size == 0:
        diff_x = 0
        diff_y = 0
    else:
        # Calculate distances to all green dots and find the closest one
        distances = np.linalg.norm(green_coords - humvee_pos, axis=1)
        closest_green_pos = green_coords[np.argmin(distances)]
        
        # Calculate the differences in x and y coordinates
        diff_x = (closest_green_pos[1] - humvee_pos[1]) / image.shape[1]
        diff_y = (closest_green_pos[0] - humvee_pos[0]) / image.shape[0]
    
    # Squish the humvee position coordinates between 0 and 1
    humvee_x = humvee_pos[1] / image.shape[1]
    humvee_y = humvee_pos[0] / image.shape[0]
    
    last_input = np.zeros(9, dtype=np.float32)
    last_input[prev_input] = 1.0

    return [
        *last_input,
        humvee_x,
        humvee_y,
        1.0-humvee_x,
        1.0-humvee_y,
        diff_x / 1.5,
        diff_y / 1.5
        ]

# %%
import pyautogui
import keyboard

region = {'top': 776, 'left': 57, 'width': 321 - 57, 'height': 1039 - 776}
def move_humvee(direction_index, humvee_pos):
    direction_vectors = {
        0: (0, 0),      # No movement
        1: (0, 1),      # North
        2: (1, 1),      # Northeast
        3: (1, 0),      # East
        4: (1, -1),     # Southeast
        5: (0, -1),     # South
        6: (-1, -1),    # Southwest
        7: (-1, 0),     # West
        8: (-1, 1)      # Northwest
    }

    # Get the direction vector
    direction_vector = direction_vectors.get(direction_index, (0, 0))

    # Calculate the target position
    offset = 20
    target_x = humvee_pos[0] + direction_vector[0] * offset
    target_y = humvee_pos[1] + direction_vector[1] * offset
    
    x_min = region['left']
    x_max = region['left'] + region['width']
    y_min = region['top']
    y_max = region['top'] + region['height']

    # Constrain target_x and target_y to be within the region
    target_x = max(x_min, min(target_x, x_max - 1))
    target_y = max(y_min, min(target_y, y_max - 1))

    # Perform the right-click action
    if direction_index != 0:
        pyautogui.rightClick(x=target_x, y=target_y)
    else:
        keyboard.press_and_release('s')
    pyautogui.leftClick(x=humvee_pos[0], y=humvee_pos[1])
    pyautogui.moveTo(20, 20)
    print(f"Right-clicked at position: ({target_x}, {target_y})")

# Example usage (you should call this function with the actual index):
# move_humvee(max_index)

# %%
import time
import keyboard
import mss

# Initialize a variable to control the while loop
running = True
paused = False

def toggle_pause():
    global paused
    paused = not paused
    if paused:
        print("Loop paused.")
    else:
        print("Loop resumed.")

def exit_program():
    global running
    running = False
    print("Exiting program.")

keyboard.add_hotkey('F6', toggle_pause)
keyboard.add_hotkey('F7', exit_program)

print("Program started. Press F6 to pause/resume and F7 to exit.")

prev_action = 0

with mss.mss() as sct:
    while running:
        if not paused:
            screenshot = sct.grab(region)
            screenshot_np = np.array(screenshot)

            # Apply the filter to the captured image
            filtered_image = filter_image(screenshot_np)

            # Get the state
            state = get_state(filtered_image, prev_action)
            formatted_state = tf.expand_dims(tf.constant(state, dtype=tf.float32), axis=0)
            action = q_eval.predict(formatted_state, verbose=False)
            action_values = action.flatten()  # Flatten in case it's a 2D tensor (batch size, num_actions)

            # Find the index of the maximum value
            max_index = tf.argmax(action_values).numpy()  # or use action_values.argmax() for NumPy array
            prev_action = max_index
            humvee_pos = get_humvee_position(filtered_image)
            if (humvee_pos):
                move_humvee(max_index, [humvee_pos[0]+region['left'], humvee_pos[1]+region['top'] ])

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        

cv2.destroyAllWindows()

print("Program exited.")
# Out:
# Program started. Press F6 to pause/resume and F7 to exit.
# Right-clicked at position: (126.5, 1027.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (106.5, 907.5)
# Right-clicked at position: (102.5, 927.5)
# Right-clicked at position: (118.5, 911.5)
# Right-clicked at position: (98.5, 931.5)
# Right-clicked at position: (114.5, 915.5)
# Right-clicked at position: (92.5, 917.5)
# Right-clicked at position: (88.5, 917.5)
# Right-clicked at position: (82.5, 915.5)
# Right-clicked at position: (115.5, 935.5)
# Right-clicked at position: (73.5, 915.5)
# Right-clicked at position: (73.5, 919.5)
# Right-clicked at position: (69.5, 917.5)
# Right-clicked at position: (63.5, 937.5)
# Right-clicked at position: (77.5, 919.5)
# Right-clicked at position: (57, 921.5)
# Right-clicked at position: (57, 941.5)
# Right-clicked at position: (68.5, 924.0)
# Right-clicked at position: (57, 946.5)
# Right-clicked at position: (57, 950.5)
# Right-clicked at position: (57, 956.5)
# Right-clicked at position: (82.5, 962.5)
# Right-clicked at position: (57, 946.5)
# Right-clicked at position: (68.5, 968.5)
# Right-clicked at position: (57, 968.5)
# Right-clicked at position: (57, 972.5)
# Right-clicked at position: (57, 961.6666666666666)
# Right-clicked at position: (62.5, 983.5)
# Right-clicked at position: (57, 961.6666666666666)
# Right-clicked at position: (82.5, 943.5)
# Right-clicked at position: (126.5, 1027.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (126.5, 907.5)
# Right-clicked at position: (106.5, 907.5)
# Right-clicked at position: (104.5, 907.5)
# Right-clicked at position: (98.5, 927.5)
# Right-clicked at position: (114.5, 909.5)
# Right-clicked at position: (92.5, 911.5)
# Right-clicked at position: (88.5, 931.5)
# Right-clicked at position: (104.5, 913.5)
# Right-clicked at position: (82.5, 915.5)
# Right-clicked at position: (80.0, 915.5)
# Right-clicked at position: (73.5, 913.5)
# Right-clicked at position: (67.5, 933.5)
# Right-clicked at position: (81.5, 915.5)
# Right-clicked at position: (79.5, 917.5)
# Right-clicked at position: (59.5, 917.5)
# Right-clicked at position: (57, 917.5)
# Right-clicked at position: (57, 935.5)
# Right-clicked at position: (66.5, 919.5)
# Right-clicked at position: (57, 941.5)
# Right-clicked at position: (57, 946.5)
# Right-clicked at position: (57, 952.5)
# Right-clicked at position: (57, 958.5)
# Right-clicked at position: (57, 964.5)
# Right-clicked at position: (57, 970.5)
# Right-clicked at position: (57, 977.0)
# Right-clicked at position: (62.5, 965.5)
# Right-clicked at position: (57, 985.5)
# Right-clicked at position: (57, 989.5)
# Right-clicked at position: (62.5, 975.5)
# Right-clicked at position: (57, 997.5)
# Right-clicked at position: (62.5, 981.5)
# Right-clicked at position: (62.5, 1003.5)
# Right-clicked at position: (57, 1007.5)
# Right-clicked at position: (62.5, 1014.5)
# Right-clicked at position: (62.5, 1020.5)
# Right-clicked at position: (62.5, 988.5)
# Right-clicked at position: (60.5, 1028.5)
# Right-clicked at position: (78.5, 1028.5)
# Right-clicked at position: (62.5, 1032.5)
# Right-clicked at position: (64.5, 1036.5)
# Right-clicked at position: (57, 1038)
# Right-clicked at position: (62.5, 1011.5)
# Right-clicked at position: (80.5, 1031.5)
# Right-clicked at position: (62.5, 1038)
# Right-clicked at position: (57, 1038)
# Right-clicked at position: (62.5, 1038)
# Right-clicked at position: (57, 1013.5)
# Right-clicked at position: (57, 1009.5)
# Right-clicked at position: (57, 1005.5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 41
#      39 state = get_state(filtered_image, prev_action)
#      40 formatted_state = tf.expand_dims(tf.constant(state, dtype=tf.float32), axis=0)
# ---> 41 action = q_eval.predict(formatted_state, verbose=False)
#      42 action_values = action.flatten()  # Flatten in case it's a 2D tensor (batch size, num_actions)
#      44 # Find the index of the maximum value
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\keras\engine\training.py:2249, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2247 callbacks.on_predict_begin()
#    2248 batch_outputs = None
# -> 2249 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2250     with data_handler.catch_stop_iteration():
#    2251         for step in data_handler.steps():
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\keras\engine\data_adapter.py:1307, in DataHandler.enumerate_epochs(self)
#    1305 """Yields `(epoch, tf.data.Iterator)`."""
#    1306 with self._truncate_execution_to_epoch():
# -> 1307     data_iterator = iter(self._dataset)
#    1308     for epoch in range(self._initial_epoch, self._epochs):
#    1309         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:499, in DatasetV2.__iter__(self)
#     497 if context.executing_eagerly() or ops.inside_function():
#     498   with ops.colocate_with(self._variant_tensor):
# --> 499     return iterator_ops.OwnedIterator(self)
#     500 else:
#     501   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     502                      "iteration in eager mode or within tf.function.")
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:696, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     692   if (components is not None or element_spec is not None):
#     693     raise ValueError(
#     694         "When `dataset` is provided, `element_spec` and `components` must "
#     695         "not be specified.")
# --> 696   self._create_iterator(dataset)
#     698 self._get_next_call_count = 0
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:721, in OwnedIterator._create_iterator(self, dataset)
#     716 with ops.colocate_with(ds_variant):
#     717   self._iterator_resource = (
#     718       gen_dataset_ops.anonymous_iterator_v3(
#     719           output_types=self._flat_output_types,
#     720           output_shapes=self._flat_output_shapes))
# --> 721   gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\patri\Desktop\projects\reinforcement-1\.venv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3408, in make_iterator(dataset, iterator, name)
#    3406 if tld.is_eager:
#    3407   try:
# -> 3408     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3409       _ctx, "MakeIterator", name, dataset, iterator)
#    3410     return _result
#    3411   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
